# %%
print(100)
print(100+200)
print("abc")
print('abc')
print('''abc''')
print()

print("""aaaa
bbbb
cccc
dddd""")
print()

print('''
      aaaa
      bbbb
      cccc
      dddd''')
# Out:
# 100
# 300
# abc
# abc
# abc
#
# aaaa
# bbbb
# cccc
# dddd
#
#
#       aaaa
#       bbbb
#       cccc
#       dddd

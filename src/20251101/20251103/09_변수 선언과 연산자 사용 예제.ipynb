# %%
a=500
b=200
c=a+b
d=a-b
print(a+b)
print(a-b)
print(c*3, d, a, "korea")
print("")
print("a의 값은 : ", a)
print("b의 값은 : ", b)
print("a+b = ", c, "       a-b = ",d)
# Out:
# 700
# 300
# 2100 300 500 korea
#
# a의 값은 :  500
# b의 값은 :  200
# a+b =  700        a-b =  300

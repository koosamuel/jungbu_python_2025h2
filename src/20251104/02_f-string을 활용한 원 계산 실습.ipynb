# %%
pi = 3.141592565
r = 10

# 변수 참조
print(f"원주율 = {pi}")
print(f"반지름 = {r}")
print(f"원의 둘레 = {2*pi*r}")
print(f"원의 넓이 = {pi*r*r}")
# Out:
# 원주율 = 3.141592565
# 반지름 = 10
# 원의 둘레 = 62.8318513
# 원의 넓이 = 314.15925649999997

# %%
# 사용자가 키보드로 값을 입력 : input

a = input() # 키보드로 부터 문자열을 입력받는 함수
b = input("두번째 값을 입력 : ")
print(f"첫번째는 {a}, 두번째는 {b} ===> 두 문자의 합은 {a+b}")
# Out:
#  1
# 두번째 값을 입력 :  2
# 첫번째는 1, 두번째는 2 ===> 두 문자의 합은 12

# %%
# 조건문 _ if - else 문

x = int(input("점수 입력 : "))
if (x >= 70):
    print("합격입니다")
    print("축하합니다")
else:
    print("불합격입니다")
    print("다시한번 파이팅!!!")

print("수고하셨습니다")
# Out:
# 점수 입력 :  80
# 합격입니다
# 축하합니다
# 수고하셨습니다

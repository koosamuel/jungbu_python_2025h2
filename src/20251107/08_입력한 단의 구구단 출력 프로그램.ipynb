# %%
# 입력받은 부분의 구구단을 출력

dan = int(input("원하는 단? : "))
for i in range(1, 9+1, 1):
    print(f"{dan} * {i} = {dan*i}")
# Out:
# 원하는 단? :  5
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45

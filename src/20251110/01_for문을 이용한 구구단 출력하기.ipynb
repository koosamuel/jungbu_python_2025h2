# %%
# 원하는 구구단 출력

n = int(input("단 : "))
for i in range(1, 9+1) :
    print(f"{n} * {i} = {n*i}")
# Out:
# 단 :  4
# 4 * 1 = 4
# 4 * 2 = 8
# 4 * 3 = 12
# 4 * 4 = 16
# 4 * 5 = 20
# 4 * 6 = 24
# 4 * 7 = 28
# 4 * 8 = 32
# 4 * 9 = 36

# %%
import csv      # 기본 모듈
import folium

f1 = open('../../data/서울지역_대학교_위치.csv', encoding='utf8')
loc_data=csv.reader(f1)
next(loc_data)              # 1행 제거
loc_data=list(loc_data)     # list형태로 변환

map1 = folium.Map([37.56678, 126.9782], zoom_start=12)    # 서울시청을 중심으로

for uni in loc_data:
    folium.Marker([uni[1],uni[2]],tooltip=uni[0]).add_to(map1)

map1.save("map01_대학위치.html")      # 지도를 html문서로 저장
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5bf195236f7f42a77e241a2ebd2ab537 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5bf195236f7f42a77e241a2ebd2ab537&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5bf195236f7f42a77e241a2ebd2ab537 = L.map(
#                 &quot;map_5bf195236f7f42a77e241a2ebd2ab537&quot;,
#                 {
#                     center: [37.56678, 126.9782],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1fa5b878127737201a2ac3232edfa874 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1fa5b878127737201a2ac3232edfa874.addTo(map_5bf195236f7f42a77e241a2ebd2ab537);
#
#
#             var marker_950511058b250adec8b74b35bf91fd63 = L.marker(
#                 [37.592573, 127.046737],
#                 {
# }
#             ).addTo(map_5bf195236f7f42a77e241a2ebd2ab537);
#
#
#             marker_950511058b250adec8b74b35bf91fd63.bindTooltip(
#                 `&lt;div&gt;
#                      KAIST 서울캠퍼스
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_a6e3d1f11362116353e157f38d95bf99 = L.marker(
#                 [37.5483449, 126.8547974],
#                 {
# }
#             ).addTo(map_5bf195236f7f42a77e241a2ebd2ab537);
#
#
#             marker_a6e3d1f11362116353e157f38d95bf99.bindTooltip(
#                 `&lt;div&gt;
#                      KC대학교
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_3687c0176dd354a4efcac2ad11b498e5 = L.marker(
#                 [37.5859218, 127.0043275],
#                 {
# }
#             ).addTo(map_5bf195236f7f42a77e241a2ebd2ab537);
#
#
#             marker_3687c0176dd354a4efcac2ad11b498e5.bindTooltip(
#                 `&lt;div&gt;
#                      가톨릭대학교(성신교정)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_c0e37b3513fdd0d2f975c1b1e364b236 = L.marker(
#                 [37.4996227, 127.0060653],
#                 {
# }
#             ).addTo(map_5bf195236f7f42a77e241a2ebd2ab537);
#
#
#             marker_c0e37b3513fdd0d2f975c1b1e364b236.bindTooltip(
#                 `&lt;div&gt;
#                      가톨릭대학교(성의교정)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_bec255d664c38dd9ccf2a072aa946b6e = L.marker(
#                 [37.5676455, 126.96161],
#                 {
# }
#             ).addTo(map_5bf195236f7f42a77e241a2ebd2ab537);
#
#
#             marker_bec255d664c38dd9ccf2a072aa946b6e.bindTooltip(
#                 `&lt;div&gt;
#                      감리교신학대학교
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_baf9684626a483dfe4b46315137332cd = L.marker(
#                 [37.5407625, 127.0793428],
#                 {
# }
#             ).addTo(map_5bf195236f7f42a77e241a2ebd2ab537);
#
#
#             marker_baf9684626a483dfe4b46315137332cd.bindTooltip(
#                 `&lt;div&gt;
#                      건국대학교
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_575ca4897ef4ce7f916564730fd3ee3e = L.marker(
#                 [37.300485, 127.035833],
#                 {
# }
#             ).addTo(map_5bf195236f7f42a77e241a2ebd2ab537);
#
#
#             marker_575ca4897ef4ce7f916564730fd3ee3e.bindTooltip(
#                 `&lt;div&gt;
#                      경기대학교 서울캠퍼스
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_5a9cd1557125e264ef9ec664c12e3902 = L.marker(
#                 [37.5961951, 127.052544],
#                 {
# }
#             ).addTo(map_5bf195236f7f42a77e241a2ebd2ab537);
#
#
#             marker_5a9cd1557125e264ef9ec664c12e3902.bindTooltip(
#                 `&lt;div&gt;
#                      경희대학교 서울캠퍼스
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_6c25fe31041b5fc327a82001ede143a8 = L.marker(
#                 [37.5907, 127.0277],
#                 {
# }
#             ).addTo(map_5bf195236f7f42a77e241a2ebd2ab537);
#
#
#             marker_6c25fe31041b5fc327a82001ede143a8.bindTooltip(
#                 `&lt;div&gt;
#                      고려대학교
#                  &lt;/div&gt;`,
#                 {
#   &quot;
